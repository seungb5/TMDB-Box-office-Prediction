# %%
import pandas as pd

# %%
# %pwd
# Out:
# 'C:\\Users\\tmznq\\workspace\\ml_scratch\\TMDB-Box-office-Prediction'

# %%
features = pd.read_excel('../TMDB-Box-office-Prediction/변수 정보.xlsx', index_col='변수')

# %%
features[:22].fillna('')
# Out:
#                       필요유무 중요도 순위  \
# 변수
# belongs_to_collection
# budget
# cast
# crew
# genres
# homepage
# id                       무
# imdb_id                  무
# Keywords
# original_language
# original_title
# overview                 무
# popularity               무
# poster_path              무
# production_companies
# production_countries
# release_date
# runtime
# spoken_languages
# status                   무
# tagline
# title
#
#                                                                       설명  \
# 변수
# belongs_to_collection  - 시리즈 이름 & 유무 (dict)\n- 범주형\n- train 내 2396/30...
# budget                 - 예산\n- 연속형\n- top 0(812), 15000000(72)\n- gro...
# cast                   - 출연진\n- 이름, 성별, 캐릭터 등 (dict)\n- 범주형\n- top 15...
# crew                   - 제작진\n- 이름, 부서, 직함, 성별 등 (dict)\n- 범주형\n- 2(1...
# genres                 - 장르 (dict)\n- 범주형\n- top 2(972), 3(900) / las...
# homepage                  - 영화 홈페이지 & 유무\n- 범주형\n- train 내 결측치 2054/3000
# ...
